# %% [markdown]
# <a href="https://colab.research.google.com/github/slunara/car_damage_detector/blob/main/models/EfficientNetV2S_car_damage_classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car damage classifier
#
# EfficientNetV2S pre trained model is used to classify where the image contain the damaged car or not.

# %%
#import necessary librabry
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Download data
#
# Two datasets are used

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anujms/car-damage-detection")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Downloading from https://www.kaggle.com/api/v1/datasets/download/anujms/car-damage-detection?dataset_version_number=1...
# 100%|██████████| 123M/123M [00:06<00:00, 18.5MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1

# %%
import os

# Define the dataset path
dataset_path = "/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a"

# List files and folders
os.listdir(dataset_path)
# Out:
# ['training', 'validation']

# %%
#defining the base, train and validation directory path
base_dir = "/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a"
train_dir = os.path.join(base_dir, 'training')
validation_dir = os.path.join(base_dir, 'validation')

# %%
#defining the damage and whole , train and validation directory
train_damage_dir = os.path.join(train_dir, '00-damage')
train_whole_dir = os.path.join(train_dir, '01-whole')
validation_damage_dir = os.path.join(validation_dir, '00-damage')
validation_whole_dir = os.path.join(validation_dir, '01-whole')

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# Data Augmentation is used to:
# 1. Rescale the data
# 2. to bring all the image to same dimension  i.e. 150x150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.

# %% [markdown]
# ## Fine tune EfficientNetV2S

# %% [markdown]
# For training 1840 images are used.
# For Validation 460 image are used.

# %% [markdown]
# Training and evaluating the model with binary crossentropy loss, accuracy, precision , recall

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.applications import EfficientNetV2S  # EfficientNetV2 Small
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D

# Load EfficientNetV2 base model (without top layers)
base_model = EfficientNetV2S(input_shape=(150, 150, 3), include_top=False, weights="imagenet")

# Freeze the base model layers to prevent training in the first few epochs
base_model.trainable = False  # Set to True if fine-tuning later

# Add custom layers on top of EfficientNetV2
x = GlobalAveragePooling2D()(base_model.output)  # Better than Flatten for EfficientNet
x = Dense(512, activation="relu")(x)
x = Dropout(0.3)(x)  # Helps prevent overfitting
x = Dense(1, activation="sigmoid")(x)  # Binary classification

# Define final model
model = Model(base_model.input, x)

# Compile the model
model.compile(loss="binary_crossentropy",
              optimizer=RMSprop(learning_rate=1e-4),
              metrics=["accuracy", "Precision", "Recall"])

# Train the model
history = model.fit(
    train_generator,
    epochs=50,
    validation_data=validation_generator,
    verbose=2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
# Epoch 1/50
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 92/92 - 72s - 777ms/step - Precision: 0.5599 - Recall: 0.6196 - accuracy: 0.5663 - loss: 0.6775 - val_Precision: 0.7228 - val_Recall: 0.3174 - val_accuracy: 0.5978 - val_loss: 0.6663
# Epoch 2/50
# 92/92 - 6s - 68ms/step - Precision: 0.6043 - Recall: 0.6391 - accuracy: 0.6103 - loss: 0.6563 - val_Precision: 0.6131 - val_Recall: 0.8130 - val_accuracy: 0.6500 - val_loss: 0.6383
# Epoch 3/50
# 92/92 - 8s - 87ms/step - Precision: 0.6247 - Recall: 0.6696 - accuracy: 0.6337 - loss: 0.6464 - val_Precision: 0.6357 - val_Recall: 0.7739 - val_accuracy: 0.6652 - val_loss: 0.6279
# Epoch 4/50
# 92/92 - 7s - 74ms/step - Precision: 0.6360 - Recall: 0.6761 - accuracy: 0.6446 - loss: 0.6354 - val_Precision: 0.7011 - val_Recall: 0.5609 - val_accuracy: 0.6609 - val_loss: 0.6192
# Epoch 5/50
# 92/92 - 6s - 63ms/step - Precision: 0.6345 - Recall: 0.6641 - accuracy: 0.6408 - loss: 0.6273 - val_Precision: 0.6615 - val_Recall: 0.7391 - val_accuracy: 0.6804 - val_loss: 0.6112
# Epoch 6/50
# 92/92 - 7s - 81ms/step - Precision: 0.6485 - Recall: 0.6837 - accuracy: 0.6565 - loss: 0.6210 - val_Precision: 0.8049 - val_Recall: 0.4304 - val_accuracy: 0.6630 - val_loss: 0.6189
# Epoch 7/50
# 92/92 - 6s - 63ms/step - Precision: 0.6721 - Recall: 0.6707 - accuracy: 0.6717 - loss: 0.6116 - val_Precision: 0.7020 - val_Recall: 0.6043 - val_accuracy: 0.6739 - val_loss: 0.6008
# Epoch 8/50
# 92/92 - 7s - 71ms/step - Precision: 0.6670 - Recall: 0.6728 - accuracy: 0.6685 - loss: 0.6068 - val_Precision: 0.6680 - val_Recall: 0.7522 - val_accuracy: 0.6891 - val_loss: 0.5956
# Epoch 9/50
# 92/92 - 6s - 64ms/step - Precision: 0.6711 - Recall: 0.6630 - accuracy: 0.6690 - loss: 0.6100 - val_Precision: 0.6629 - val_Recall: 0.7609 - val_accuracy: 0.6870 - val_loss: 0.5922
# Epoch 10/50
# 92/92 - 8s - 88ms/step - Precision: 0.6520 - Recall: 0.6783 - accuracy: 0.6582 - loss: 0.6103 - val_Precision: 0.7515 - val_Recall: 0.5391 - val_accuracy: 0.6804 - val_loss: 0.5939
# Epoch 11/50
# 92/92 - 8s - 91ms/step - Precision: 0.6719 - Recall: 0.6565 - accuracy: 0.6679 - loss: 0.6030 - val_Precision: 0.7009 - val_Recall: 0.6826 - val_accuracy: 0.6957 - val_loss: 0.5870
# Epoch 12/50
# 92/92 - 10s - 105ms/step - Precision: 0.6829 - Recall: 0.6717 - accuracy: 0.6799 - loss: 0.5952 - val_Precision: 0.7446 - val_Recall: 0.5957 - val_accuracy: 0.6957 - val_loss: 0.5836
# Epoch 13/50
# 92/92 - 6s - 71ms/step - Precision: 0.6780 - Recall: 0.6707 - accuracy: 0.6761 - loss: 0.5962 - val_Precision: 0.7291 - val_Recall: 0.6435 - val_accuracy: 0.7022 - val_loss: 0.5831
# Epoch 14/50
# 92/92 - 6s - 66ms/step - Precision: 0.6721 - Recall: 0.6750 - accuracy: 0.6728 - loss: 0.5947 - val_Precision: 0.7947 - val_Recall: 0.5217 - val_accuracy: 0.6935 - val_loss: 0.5808
# Epoch 15/50
# 92/92 - 7s - 71ms/step - Precision: 0.6982 - Recall: 0.6815 - accuracy: 0.6935 - loss: 0.5890 - val_Precision: 0.7811 - val_Recall: 0.5739 - val_accuracy: 0.7065 - val_loss: 0.5738
# Epoch 16/50
# 92/92 - 6s - 67ms/step - Precision: 0.6908 - Recall: 0.6848 - accuracy: 0.6891 - loss: 0.5857 - val_Precision: 0.8143 - val_Recall: 0.4957 - val_accuracy: 0.6913 - val_loss: 0.5812
# Epoch 17/50
# 92/92 - 7s - 74ms/step - Precision: 0.6907 - Recall: 0.6674 - accuracy: 0.6842 - loss: 0.5873 - val_Precision: 0.7778 - val_Recall: 0.5478 - val_accuracy: 0.6957 - val_loss: 0.5737
# Epoch 18/50
# 92/92 - 7s - 79ms/step - Precision: 0.6963 - Recall: 0.6804 - accuracy: 0.6918 - loss: 0.5834 - val_Precision: 0.7387 - val_Recall: 0.6391 - val_accuracy: 0.7065 - val_loss: 0.5664
# Epoch 19/50
# 92/92 - 6s - 64ms/step - Precision: 0.6945 - Recall: 0.6772 - accuracy: 0.6897 - loss: 0.5809 - val_Precision: 0.7217 - val_Recall: 0.7217 - val_accuracy: 0.7217 - val_loss: 0.5581
# Epoch 20/50
# 92/92 - 7s - 73ms/step - Precision: 0.6927 - Recall: 0.6837 - accuracy: 0.6902 - loss: 0.5791 - val_Precision: 0.8264 - val_Recall: 0.4348 - val_accuracy: 0.6717 - val_loss: 0.5827
# Epoch 21/50
# 92/92 - 6s - 64ms/step - Precision: 0.7028 - Recall: 0.6761 - accuracy: 0.6951 - loss: 0.5719 - val_Precision: 0.6988 - val_Recall: 0.7565 - val_accuracy: 0.7152 - val_loss: 0.5590
# Epoch 22/50
# 92/92 - 7s - 74ms/step - Precision: 0.6988 - Recall: 0.6783 - accuracy: 0.6929 - loss: 0.5798 - val_Precision: 0.7393 - val_Recall: 0.6783 - val_accuracy: 0.7196 - val_loss: 0.5549
# Epoch 23/50
# 92/92 - 6s - 64ms/step - Precision: 0.7097 - Recall: 0.6750 - accuracy: 0.6995 - loss: 0.5792 - val_Precision: 0.7488 - val_Recall: 0.6609 - val_accuracy: 0.7196 - val_loss: 0.5555
# Epoch 24/50
# 92/92 - 7s - 72ms/step - Precision: 0.7009 - Recall: 0.6750 - accuracy: 0.6935 - loss: 0.5775 - val_Precision: 0.6599 - val_Recall: 0.8522 - val_accuracy: 0.7065 - val_loss: 0.5669
# Epoch 25/50
# 92/92 - 6s - 63ms/step - Precision: 0.6994 - Recall: 0.6804 - accuracy: 0.6940 - loss: 0.5753 - val_Precision: 0.6992 - val_Recall: 0.7783 - val_accuracy: 0.7217 - val_loss: 0.5546
# Epoch 26/50
# 92/92 - 7s - 71ms/step - Precision: 0.7031 - Recall: 0.6848 - accuracy: 0.6978 - loss: 0.5734 - val_Precision: 0.7758 - val_Recall: 0.5565 - val_accuracy: 0.6978 - val_loss: 0.5561
# Epoch 27/50
# 92/92 - 6s - 65ms/step - Precision: 0.6845 - Recall: 0.6533 - accuracy: 0.6761 - loss: 0.5771 - val_Precision: 0.7186 - val_Recall: 0.7217 - val_accuracy: 0.7196 - val_loss: 0.5462
# Epoch 28/50
# 92/92 - 7s - 75ms/step - Precision: 0.7012 - Recall: 0.6837 - accuracy: 0.6962 - loss: 0.5719 - val_Precision: 0.7935 - val_Recall: 0.5348 - val_accuracy: 0.6978 - val_loss: 0.5557
# Epoch 29/50
# 92/92 - 6s - 64ms/step - Precision: 0.7064 - Recall: 0.6696 - accuracy: 0.6957 - loss: 0.5692 - val_Precision: 0.6894 - val_Recall: 0.7913 - val_accuracy: 0.7174 - val_loss: 0.5504
# Epoch 30/50
# 92/92 - 7s - 73ms/step - Precision: 0.7121 - Recall: 0.6989 - accuracy: 0.7082 - loss: 0.5618 - val_Precision: 0.8088 - val_Recall: 0.4783 - val_accuracy: 0.6826 - val_loss: 0.5658
# Epoch 31/50
# 92/92 - 6s - 64ms/step - Precision: 0.7156 - Recall: 0.6783 - accuracy: 0.7043 - loss: 0.5713 - val_Precision: 0.7476 - val_Recall: 0.6696 - val_accuracy: 0.7217 - val_loss: 0.5446
# Epoch 32/50
# 92/92 - 7s - 72ms/step - Precision: 0.6921 - Recall: 0.6696 - accuracy: 0.6859 - loss: 0.5676 - val_Precision: 0.7730 - val_Recall: 0.6217 - val_accuracy: 0.7196 - val_loss: 0.5437
# Epoch 33/50
# 92/92 - 10s - 111ms/step - Precision: 0.7125 - Recall: 0.6870 - accuracy: 0.7049 - loss: 0.5599 - val_Precision: 0.8462 - val_Recall: 0.4783 - val_accuracy: 0.6957 - val_loss: 0.5701
# Epoch 34/50
# 92/92 - 6s - 63ms/step - Precision: 0.7194 - Recall: 0.6717 - accuracy: 0.7049 - loss: 0.5588 - val_Precision: 0.7119 - val_Recall: 0.7304 - val_accuracy: 0.7174 - val_loss: 0.5384
# Epoch 35/50
# 92/92 - 7s - 71ms/step - Precision: 0.6993 - Recall: 0.6978 - accuracy: 0.6989 - loss: 0.5601 - val_Precision: 0.7736 - val_Recall: 0.5348 - val_accuracy: 0.6891 - val_loss: 0.5477
# Epoch 36/50
# 92/92 - 6s - 66ms/step - Precision: 0.7096 - Recall: 0.6772 - accuracy: 0.7000 - loss: 0.5613 - val_Precision: 0.7043 - val_Recall: 0.7870 - val_accuracy: 0.7283 - val_loss: 0.5418
# Epoch 37/50
# 92/92 - 7s - 72ms/step - Precision: 0.7213 - Recall: 0.6978 - accuracy: 0.7141 - loss: 0.5569 - val_Precision: 0.7373 - val_Recall: 0.6957 - val_accuracy: 0.7239 - val_loss: 0.5348
# Epoch 38/50
# 92/92 - 6s - 63ms/step - Precision: 0.7160 - Recall: 0.6935 - accuracy: 0.7092 - loss: 0.5573 - val_Precision: 0.6850 - val_Recall: 0.8130 - val_accuracy: 0.7196 - val_loss: 0.5439
# Epoch 39/50
# 92/92 - 7s - 73ms/step - Precision: 0.7245 - Recall: 0.6859 - accuracy: 0.7125 - loss: 0.5528 - val_Precision: 0.7635 - val_Recall: 0.6739 - val_accuracy: 0.7326 - val_loss: 0.5319
# Epoch 40/50
# 92/92 - 6s - 63ms/step - Precision: 0.7218 - Recall: 0.6880 - accuracy: 0.7114 - loss: 0.5536 - val_Precision: 0.8425 - val_Recall: 0.4652 - val_accuracy: 0.6891 - val_loss: 0.5635
# Epoch 41/50
# 92/92 - 7s - 71ms/step - Precision: 0.7141 - Recall: 0.6924 - accuracy: 0.7076 - loss: 0.5559 - val_Precision: 0.8129 - val_Recall: 0.4913 - val_accuracy: 0.6891 - val_loss: 0.5516
# Epoch 42/50
# 92/92 - 11s - 118ms/step - Precision: 0.7287 - Recall: 0.6978 - accuracy: 0.7190 - loss: 0.5431 - val_Precision: 0.8397 - val_Recall: 0.4783 - val_accuracy: 0.6935 - val_loss: 0.5600
# Epoch 43/50
# 92/92 - 6s - 65ms/step - Precision: 0.7171 - Recall: 0.7000 - accuracy: 0.7120 - loss: 0.5419 - val_Precision: 0.7455 - val_Recall: 0.7130 - val_accuracy: 0.7348 - val_loss: 0.5282
# Epoch 44/50
# 92/92 - 6s - 70ms/step - Precision: 0.7109 - Recall: 0.6870 - accuracy: 0.7038 - loss: 0.5564 - val_Precision: 0.7031 - val_Recall: 0.7826 - val_accuracy: 0.7261 - val_loss: 0.5369
# Epoch 45/50
# 92/92 - 6s - 64ms/step - Precision: 0.7081 - Recall: 0.6935 - accuracy: 0.7038 - loss: 0.5511 - val_Precision: 0.7826 - val_Recall: 0.6261 - val_accuracy: 0.7261 - val_loss: 0.5306
# Epoch 46/50
# 92/92 - 6s - 71ms/step - Precision: 0.7323 - Recall: 0.6989 - accuracy: 0.7217 - loss: 0.5479 - val_Precision: 0.7149 - val_Recall: 0.7739 - val_accuracy: 0.7326 - val_loss: 0.5255
# Epoch 47/50
# 92/92 - 6s - 63ms/step - Precision: 0.7246 - Recall: 0.7120 - accuracy: 0.7207 - loss: 0.5438 - val_Precision: 0.8075 - val_Recall: 0.5652 - val_accuracy: 0.7152 - val_loss: 0.5339
# Epoch 48/50
# 92/92 - 7s - 72ms/step - Precision: 0.7222 - Recall: 0.6837 - accuracy: 0.7103 - loss: 0.5417 - val_Precision: 0.7853 - val_Recall: 0.6522 - val_accuracy: 0.7370 - val_loss: 0.5278
# Epoch 49/50
# 92/92 - 6s - 64ms/step - Precision: 0.7372 - Recall: 0.7196 - accuracy: 0.7315 - loss: 0.5357 - val_Precision: 0.6818 - val_Recall: 0.8478 - val_accuracy: 0.7261 - val_loss: 0.5412
# Epoch 50/50
# 92/92 - 7s - 71ms/step - Precision: 0.7195 - Recall: 0.6913 - accuracy: 0.7109 - loss: 0.5445 - val_Precision: 0.7224 - val_Recall: 0.7696 - val_accuracy: 0.7370 - val_loss: 0.5255

# %%
#weights saving
model.save("classifier.keras")

# %% [markdown]
# ## Results

# %% [markdown]
# plotting the history of train and validation loss, accurcy, precision, recall

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
acc = history.history['Precision']
val_acc = history.history['val_Precision']
loss = history.history['Recall']
val_loss = history.history['val_Recall']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# Testing

# %%
import cv2
im = cv2.imread("/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a/validation/00-damage/0001.JPEG")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (150, 150))
imS=im.reshape([1,150,150,3])
pred=model.predict(np.array(imS))
if pred[0][0]>0.5:
    print("The car is damaged")
else:
    print("The car is not damaged")
plt.axis("off")
plt.imshow(im)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 11s 11s/step
# The car is damaged

# %%
im = cv2.imread("/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a/validation/01-whole/0006.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (150, 150))
imS=im.reshape([1,150,150,3])
pred=model.predict(np.array(imS))
print(pred)
if pred[0][0]>0.5:
    print("The car is damaged")
else:
    print("The car is not damaged")
plt.axis("off")
plt.imshow(im)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# [[0.9395334]]
# The car is damaged

# %% [markdown]
# Conclusion: Successfully build a classifier to classify the images containing into damage and undamage cars.

# %% [markdown]
# # Inference - SURA data

# %%
# Clone the GitHub repo
repo_url = "https://github.com/slunara/car_damage_detector.git"
# !git clone {repo_url}

test_data_dir = "car_damage_detector/test_data"

assert os.path.exists(test_data_dir), "Test data folder not found!"
print("Test data downloaded successfully!")
# Out:
# Cloning into 'car_damage_detector'...
# remote: Enumerating objects: 189, done.
# remote: Counting objects: 100% (189/189), done.
# remote: Compressing objects: 100% (184/184), done.
# remote: Total 189 (delta 18), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (189/189), 13.06 MiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (18/18), done.
# Test data downloaded successfully!

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input
import matplotlib.pyplot as plt

# Define image size
IMG_SIZE = (150, 150)

# Define class labels (damage = 1, whole = 0)
class_labels = {"damage": 1, "whole": 0}

# Function to load and preprocess images
def load_and_preprocess_image(image_path):
    img = load_img(image_path, target_size=IMG_SIZE)  # Load and resize
    img_array = img_to_array(img)  # Convert to numpy array
    img_array = preprocess_input(img_array)  # Normalize
    return img_array

# Function to load test images from both classes
def load_test_images(test_data_dir):
    test_images = []
    test_labels = []
    test_filenames = []

    for category in ["damage", "whole"]:  # Iterate over both classes
        folder_path = os.path.join(test_data_dir, category)

        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            img_array = load_and_preprocess_image(img_path)
            test_images.append(img_array)
            test_labels.append(class_labels[category])
            test_filenames.append(img_name)

    return np.array(test_images), np.array(test_labels), test_filenames

# Load test images
X_test, y_test, filenames = load_test_images(test_data_dir)

print(f"Loaded {len(X_test)} test images!")
# Out:
# Loaded 151 test images!

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_labels = (y_pred > 0.5).astype(int)  # Convert probabilities to binary labels

# Evaluate the model
accuracy = np.mean(y_pred_labels.flatten() == y_test)
print(f"✅ Model Accuracy on Test Data: {accuracy * 100:.2f}%")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 22s 3s/step
# ✅ Model Accuracy on Test Data: 13.91%

# %%
from sklearn.metrics import recall_score

# Calculate recall score
recall = recall_score(y_test.flatten(), y_pred_labels)

# Print recall score
print(f"✅ Model Recall on Test Data: {recall:.4f}")
# Out:
# ✅ Model Recall on Test Data: 0.9286

# %%
# Show sample predictions
fig, axes = plt.subplots(5, 5, figsize=(10, 10))
axes = axes.ravel()

for i in range(25):
    img = load_img(os.path.join(test_data_dir, "damage" if y_test[i] == 1 else "whole", filenames[i]), target_size=IMG_SIZE)
    axes[i].imshow(img)
    axes[i].axis("off")
    axes[i].set_title(f"Actual: {'Damage' if y_test[i] == 1 else 'Whole'}\nPredicted: {'Damage' if y_pred_labels[i] == 1 else 'Whole'}")

plt.show()
