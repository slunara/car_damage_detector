# %% [markdown]
# <a href="https://colab.research.google.com/github/slunara/car_damage_detector/blob/main/models/EfficientNetV2S_car_damage_classifier_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Car damage classifier
#
# EfficientNetV2S pre trained model is used to classify where the image contain the damaged car or not.

# %%
#import necessary librabry
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %% [markdown]
# ## Download data
#
# Two datasets are used

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("anujms/car-damage-detection")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/anujms/car-damage-detection?dataset_version_number=1...
# 100%|██████████| 123M/123M [00:04<00:00, 31.6MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1

# %%
import os

# Define the dataset path
dataset_path = "/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a"

# List files and folders
os.listdir(dataset_path)
# Out:
# ['validation', 'training']

# %%
#defining the base, train and validation directory path
base_dir = "/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a"
train_dir = os.path.join(base_dir, 'training')
validation_dir = os.path.join(base_dir, 'validation')

# %%
#defining the damage and whole , train and validation directory
train_damage_dir = os.path.join(train_dir, '00-damage')
train_whole_dir = os.path.join(train_dir, '01-whole')
validation_damage_dir = os.path.join(validation_dir, '00-damage')
validation_whole_dir = os.path.join(validation_dir, '01-whole')

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# Data Augmentation is used to:
# 1. Rescale the data
# 2. to bring all the image to same dimension  i.e. 150x150

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
        validation_dir,
        target_size=(150, 150),
        batch_size=20,
        class_mode='binary')
# Out:
# Found 1840 images belonging to 2 classes.
# Found 460 images belonging to 2 classes.

# %% [markdown]
# ## Fine tune EfficientNetV2S

# %% [markdown]
# For training 1840 images are used.
# For Validation 460 image are used.

# %% [markdown]
# Training and evaluating the model with binary crossentropy loss, accuracy, precision , recall

# %%
# Import necessary modules
import tensorflow as tf
from tensorflow.keras import Model
from tensorflow.keras.applications import EfficientNetV2S  # EfficientNetV2 Small
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.layers import Flatten, Dense, Dropout, GlobalAveragePooling2D

# Load EfficientNetV2 base model (without top layers)
base_model = EfficientNetV2S(input_shape=(150, 150, 3), include_top=False, weights="imagenet")

# Freeze the base model layers to prevent training in the first few epochs
base_model.trainable = False  # Set to True if fine-tuning later

# Add custom layers on top of EfficientNetV2
x = GlobalAveragePooling2D()(base_model.output)  # Better than Flatten for EfficientNet
x = Dense(512, activation="relu")(x)
x = Dropout(0.3)(x)  # Helps prevent overfitting
x = Dense(1, activation="sigmoid")(x)  # Binary classification

# Define final model
model = Model(base_model.input, x)

# Compile the model
model.compile(loss="binary_crossentropy",
              optimizer=RMSprop(learning_rate=1e-4),
              metrics=["accuracy", "Precision", "Recall"])

# Train the model
history = model.fit(
    train_generator,
    epochs=60,
    validation_data=validation_generator,
    verbose=2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-s_notop.h5
# 82420632/82420632 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Epoch 1/60
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 92/92 - 75s - 820ms/step - Precision: 0.5648 - Recall: 0.5924 - accuracy: 0.5679 - loss: 0.6790 - val_Precision: 0.5918 - val_Recall: 0.8130 - val_accuracy: 0.6261 - val_loss: 0.6556
# Epoch 2/60
# 92/92 - 7s - 81ms/step - Precision: 0.6048 - Recall: 0.6522 - accuracy: 0.6130 - loss: 0.6543 - val_Precision: 0.6290 - val_Recall: 0.7739 - val_accuracy: 0.6587 - val_loss: 0.6390
# Epoch 3/60
# 92/92 - 8s - 84ms/step - Precision: 0.6284 - Recall: 0.6783 - accuracy: 0.6386 - loss: 0.6421 - val_Precision: 0.7554 - val_Recall: 0.4565 - val_accuracy: 0.6543 - val_loss: 0.6340
# Epoch 4/60
# 92/92 - 6s - 69ms/step - Precision: 0.6312 - Recall: 0.6326 - accuracy: 0.6315 - loss: 0.6421 - val_Precision: 0.7330 - val_Recall: 0.5609 - val_accuracy: 0.6783 - val_loss: 0.6239
# Epoch 5/60
# 92/92 - 8s - 84ms/step - Precision: 0.6478 - Recall: 0.6717 - accuracy: 0.6533 - loss: 0.6254 - val_Precision: 0.6858 - val_Recall: 0.6739 - val_accuracy: 0.6826 - val_loss: 0.6145
# Epoch 6/60
# 92/92 - 7s - 78ms/step - Precision: 0.6574 - Recall: 0.6424 - accuracy: 0.6538 - loss: 0.6207 - val_Precision: 0.6018 - val_Recall: 0.8739 - val_accuracy: 0.6478 - val_loss: 0.6187
# Epoch 7/60
# 92/92 - 10s - 103ms/step - Precision: 0.6544 - Recall: 0.6750 - accuracy: 0.6592 - loss: 0.6240 - val_Precision: 0.6732 - val_Recall: 0.7522 - val_accuracy: 0.6935 - val_loss: 0.6010
# Epoch 8/60
# 92/92 - 8s - 84ms/step - Precision: 0.6538 - Recall: 0.6652 - accuracy: 0.6565 - loss: 0.6188 - val_Precision: 0.7283 - val_Recall: 0.5826 - val_accuracy: 0.6826 - val_loss: 0.6002
# Epoch 9/60
# 92/92 - 7s - 76ms/step - Precision: 0.6692 - Recall: 0.6793 - accuracy: 0.6717 - loss: 0.6107 - val_Precision: 0.6527 - val_Recall: 0.7435 - val_accuracy: 0.6739 - val_loss: 0.5984
# Epoch 10/60
# 92/92 - 9s - 93ms/step - Precision: 0.6819 - Recall: 0.6826 - accuracy: 0.6821 - loss: 0.6007 - val_Precision: 0.6680 - val_Recall: 0.7261 - val_accuracy: 0.6826 - val_loss: 0.5927
# Epoch 11/60
# 92/92 - 9s - 99ms/step - Precision: 0.6857 - Recall: 0.6783 - accuracy: 0.6837 - loss: 0.5978 - val_Precision: 0.7190 - val_Recall: 0.6565 - val_accuracy: 0.7000 - val_loss: 0.5870
# Epoch 12/60
# 92/92 - 7s - 74ms/step - Precision: 0.6835 - Recall: 0.6761 - accuracy: 0.6815 - loss: 0.5924 - val_Precision: 0.7170 - val_Recall: 0.6609 - val_accuracy: 0.7000 - val_loss: 0.5843
# Epoch 13/60
# 92/92 - 7s - 81ms/step - Precision: 0.6815 - Recall: 0.6674 - accuracy: 0.6777 - loss: 0.5965 - val_Precision: 0.7018 - val_Recall: 0.6957 - val_accuracy: 0.7000 - val_loss: 0.5780
# Epoch 14/60
# 92/92 - 8s - 87ms/step - Precision: 0.6854 - Recall: 0.6772 - accuracy: 0.6832 - loss: 0.5861 - val_Precision: 0.8088 - val_Recall: 0.4783 - val_accuracy: 0.6826 - val_loss: 0.5884
# Epoch 15/60
# 92/92 - 8s - 83ms/step - Precision: 0.6972 - Recall: 0.6609 - accuracy: 0.6870 - loss: 0.5890 - val_Precision: 0.6493 - val_Recall: 0.8130 - val_accuracy: 0.6870 - val_loss: 0.5771
# Epoch 16/60
# 92/92 - 7s - 80ms/step - Precision: 0.6790 - Recall: 0.6804 - accuracy: 0.6793 - loss: 0.5858 - val_Precision: 0.7611 - val_Recall: 0.5957 - val_accuracy: 0.7043 - val_loss: 0.5697
# Epoch 17/60
# 92/92 - 7s - 74ms/step - Precision: 0.6872 - Recall: 0.6663 - accuracy: 0.6815 - loss: 0.5891 - val_Precision: 0.7647 - val_Recall: 0.5652 - val_accuracy: 0.6957 - val_loss: 0.5681
# Epoch 18/60
# 92/92 - 8s - 82ms/step - Precision: 0.6902 - Recall: 0.6707 - accuracy: 0.6848 - loss: 0.5824 - val_Precision: 0.7391 - val_Recall: 0.6652 - val_accuracy: 0.7152 - val_loss: 0.5606
# Epoch 19/60
# 92/92 - 7s - 81ms/step - Precision: 0.6922 - Recall: 0.6674 - accuracy: 0.6853 - loss: 0.5868 - val_Precision: 0.7246 - val_Recall: 0.7435 - val_accuracy: 0.7304 - val_loss: 0.5602
# Epoch 20/60
# 92/92 - 8s - 91ms/step - Precision: 0.7033 - Recall: 0.6880 - accuracy: 0.6989 - loss: 0.5787 - val_Precision: 0.7227 - val_Recall: 0.6913 - val_accuracy: 0.7130 - val_loss: 0.5607
# Epoch 21/60
# 92/92 - 7s - 81ms/step - Precision: 0.7040 - Recall: 0.6826 - accuracy: 0.6978 - loss: 0.5786 - val_Precision: 0.6714 - val_Recall: 0.8174 - val_accuracy: 0.7087 - val_loss: 0.5679
# Epoch 22/60
# 92/92 - 7s - 76ms/step - Precision: 0.7032 - Recall: 0.6826 - accuracy: 0.6973 - loss: 0.5744 - val_Precision: 0.7029 - val_Recall: 0.7304 - val_accuracy: 0.7109 - val_loss: 0.5592
# Epoch 23/60
# 92/92 - 8s - 84ms/step - Precision: 0.6988 - Recall: 0.6859 - accuracy: 0.6951 - loss: 0.5734 - val_Precision: 0.7315 - val_Recall: 0.6870 - val_accuracy: 0.7174 - val_loss: 0.5525
# Epoch 24/60
# 92/92 - 7s - 77ms/step - Precision: 0.7010 - Recall: 0.6880 - accuracy: 0.6973 - loss: 0.5735 - val_Precision: 0.7299 - val_Recall: 0.6696 - val_accuracy: 0.7109 - val_loss: 0.5529
# Epoch 25/60
# 92/92 - 10s - 108ms/step - Precision: 0.7080 - Recall: 0.6772 - accuracy: 0.6989 - loss: 0.5713 - val_Precision: 0.7273 - val_Recall: 0.7304 - val_accuracy: 0.7283 - val_loss: 0.5496
# Epoch 26/60
# 92/92 - 8s - 87ms/step - Precision: 0.7095 - Recall: 0.6902 - accuracy: 0.7038 - loss: 0.5728 - val_Precision: 0.6850 - val_Recall: 0.8130 - val_accuracy: 0.7196 - val_loss: 0.5553
# Epoch 27/60
# 92/92 - 8s - 83ms/step - Precision: 0.7040 - Recall: 0.6826 - accuracy: 0.6978 - loss: 0.5739 - val_Precision: 0.6353 - val_Recall: 0.9087 - val_accuracy: 0.6935 - val_loss: 0.5791
# Epoch 28/60
# 92/92 - 8s - 88ms/step - Precision: 0.7033 - Recall: 0.6880 - accuracy: 0.6989 - loss: 0.5656 - val_Precision: 0.7293 - val_Recall: 0.7261 - val_accuracy: 0.7283 - val_loss: 0.5446
# Epoch 29/60
# 92/92 - 8s - 86ms/step - Precision: 0.6967 - Recall: 0.6967 - accuracy: 0.6967 - loss: 0.5605 - val_Precision: 0.7476 - val_Recall: 0.6696 - val_accuracy: 0.7217 - val_loss: 0.5455
# Epoch 30/60
# 92/92 - 7s - 74ms/step - Precision: 0.7063 - Recall: 0.7033 - accuracy: 0.7054 - loss: 0.5632 - val_Precision: 0.7327 - val_Recall: 0.6913 - val_accuracy: 0.7196 - val_loss: 0.5436
# Epoch 31/60
# 92/92 - 8s - 82ms/step - Precision: 0.7130 - Recall: 0.6967 - accuracy: 0.7082 - loss: 0.5567 - val_Precision: 0.7016 - val_Recall: 0.7565 - val_accuracy: 0.7174 - val_loss: 0.5437
# Epoch 32/60
# 92/92 - 8s - 86ms/step - Precision: 0.7154 - Recall: 0.7022 - accuracy: 0.7114 - loss: 0.5486 - val_Precision: 0.7806 - val_Recall: 0.5261 - val_accuracy: 0.6891 - val_loss: 0.5535
# Epoch 33/60
# 92/92 - 6s - 70ms/step - Precision: 0.7262 - Recall: 0.6978 - accuracy: 0.7174 - loss: 0.5545 - val_Precision: 0.7309 - val_Recall: 0.7087 - val_accuracy: 0.7239 - val_loss: 0.5397
# Epoch 34/60
# 92/92 - 9s - 100ms/step - Precision: 0.7185 - Recall: 0.6935 - accuracy: 0.7109 - loss: 0.5549 - val_Precision: 0.7179 - val_Recall: 0.7304 - val_accuracy: 0.7217 - val_loss: 0.5394
# Epoch 35/60
# 92/92 - 6s - 69ms/step - Precision: 0.7148 - Recall: 0.6891 - accuracy: 0.7071 - loss: 0.5577 - val_Precision: 0.7149 - val_Recall: 0.7304 - val_accuracy: 0.7196 - val_loss: 0.5383
# Epoch 36/60
# 92/92 - 8s - 84ms/step - Precision: 0.6990 - Recall: 0.6815 - accuracy: 0.6940 - loss: 0.5580 - val_Precision: 0.7149 - val_Recall: 0.7739 - val_accuracy: 0.7326 - val_loss: 0.5392
# Epoch 37/60
# 92/92 - 8s - 83ms/step - Precision: 0.7065 - Recall: 0.6804 - accuracy: 0.6989 - loss: 0.5591 - val_Precision: 0.7181 - val_Recall: 0.7087 - val_accuracy: 0.7152 - val_loss: 0.5363
# Epoch 38/60
# 92/92 - 7s - 75ms/step - Precision: 0.7219 - Recall: 0.7054 - accuracy: 0.7168 - loss: 0.5529 - val_Precision: 0.7853 - val_Recall: 0.6043 - val_accuracy: 0.7196 - val_loss: 0.5414
# Epoch 39/60
# 92/92 - 8s - 83ms/step - Precision: 0.6962 - Recall: 0.6826 - accuracy: 0.6924 - loss: 0.5553 - val_Precision: 0.7977 - val_Recall: 0.6000 - val_accuracy: 0.7239 - val_loss: 0.5438
# Epoch 40/60
# 92/92 - 6s - 69ms/step - Precision: 0.7200 - Recall: 0.6902 - accuracy: 0.7109 - loss: 0.5533 - val_Precision: 0.7125 - val_Recall: 0.7435 - val_accuracy: 0.7217 - val_loss: 0.5330
# Epoch 41/60
# 92/92 - 8s - 83ms/step - Precision: 0.7410 - Recall: 0.7120 - accuracy: 0.7315 - loss: 0.5441 - val_Precision: 0.7432 - val_Recall: 0.7174 - val_accuracy: 0.7348 - val_loss: 0.5296
# Epoch 42/60
# 92/92 - 8s - 86ms/step - Precision: 0.7216 - Recall: 0.6848 - accuracy: 0.7103 - loss: 0.5525 - val_Precision: 0.7376 - val_Recall: 0.7087 - val_accuracy: 0.7283 - val_loss: 0.5311
# Epoch 43/60
# 92/92 - 7s - 78ms/step - Precision: 0.7334 - Recall: 0.6967 - accuracy: 0.7217 - loss: 0.5422 - val_Precision: 0.7431 - val_Recall: 0.7043 - val_accuracy: 0.7304 - val_loss: 0.5285
# Epoch 44/60
# 92/92 - 8s - 89ms/step - Precision: 0.7243 - Recall: 0.6880 - accuracy: 0.7130 - loss: 0.5471 - val_Precision: 0.7581 - val_Recall: 0.6130 - val_accuracy: 0.7087 - val_loss: 0.5416
# Epoch 45/60
# 92/92 - 8s - 84ms/step - Precision: 0.7223 - Recall: 0.6870 - accuracy: 0.7114 - loss: 0.5553 - val_Precision: 0.7247 - val_Recall: 0.7783 - val_accuracy: 0.7413 - val_loss: 0.5289
# Epoch 46/60
# 92/92 - 7s - 81ms/step - Precision: 0.7221 - Recall: 0.7033 - accuracy: 0.7163 - loss: 0.5493 - val_Precision: 0.7801 - val_Recall: 0.6478 - val_accuracy: 0.7326 - val_loss: 0.5316
# Epoch 47/60
# 92/92 - 8s - 88ms/step - Precision: 0.7151 - Recall: 0.6848 - accuracy: 0.7060 - loss: 0.5490 - val_Precision: 0.6934 - val_Recall: 0.8261 - val_accuracy: 0.7304 - val_loss: 0.5378
# Epoch 48/60
# 92/92 - 6s - 70ms/step - Precision: 0.7239 - Recall: 0.7011 - accuracy: 0.7168 - loss: 0.5488 - val_Precision: 0.7688 - val_Recall: 0.6652 - val_accuracy: 0.7326 - val_loss: 0.5289
# Epoch 49/60
# 92/92 - 8s - 83ms/step - Precision: 0.7316 - Recall: 0.7141 - accuracy: 0.7261 - loss: 0.5397 - val_Precision: 0.7523 - val_Recall: 0.7000 - val_accuracy: 0.7348 - val_loss: 0.5256
# Epoch 50/60
# 92/92 - 7s - 75ms/step - Precision: 0.7264 - Recall: 0.6957 - accuracy: 0.7168 - loss: 0.5480 - val_Precision: 0.6982 - val_Recall: 0.8348 - val_accuracy: 0.7370 - val_loss: 0.5367
# Epoch 51/60
# 92/92 - 7s - 78ms/step - Precision: 0.7241 - Recall: 0.6848 - accuracy: 0.7120 - loss: 0.5438 - val_Precision: 0.7109 - val_Recall: 0.7913 - val_accuracy: 0.7348 - val_loss: 0.5284
# Epoch 52/60
# 92/92 - 8s - 87ms/step - Precision: 0.7396 - Recall: 0.7130 - accuracy: 0.7310 - loss: 0.5353 - val_Precision: 0.7213 - val_Recall: 0.7652 - val_accuracy: 0.7348 - val_loss: 0.5257
# Epoch 53/60
# 92/92 - 9s - 98ms/step - Precision: 0.7083 - Recall: 0.6837 - accuracy: 0.7011 - loss: 0.5522 - val_Precision: 0.7711 - val_Recall: 0.6739 - val_accuracy: 0.7370 - val_loss: 0.5247
# Epoch 54/60
# 92/92 - 8s - 82ms/step - Precision: 0.7273 - Recall: 0.6957 - accuracy: 0.7174 - loss: 0.5467 - val_Precision: 0.7988 - val_Recall: 0.5696 - val_accuracy: 0.7130 - val_loss: 0.5345
# Epoch 55/60
# 92/92 - 8s - 87ms/step - Precision: 0.7364 - Recall: 0.6924 - accuracy: 0.7223 - loss: 0.5401 - val_Precision: 0.6721 - val_Recall: 0.8913 - val_accuracy: 0.7283 - val_loss: 0.5494
# Epoch 56/60
# 92/92 - 7s - 73ms/step - Precision: 0.7305 - Recall: 0.7130 - accuracy: 0.7250 - loss: 0.5346 - val_Precision: 0.7261 - val_Recall: 0.7609 - val_accuracy: 0.7370 - val_loss: 0.5223
# Epoch 57/60
# 92/92 - 8s - 92ms/step - Precision: 0.7268 - Recall: 0.7054 - accuracy: 0.7201 - loss: 0.5359 - val_Precision: 0.8296 - val_Recall: 0.4870 - val_accuracy: 0.6935 - val_loss: 0.5500
# Epoch 58/60
# 92/92 - 7s - 73ms/step - Precision: 0.7503 - Recall: 0.7120 - accuracy: 0.7375 - loss: 0.5280 - val_Precision: 0.7311 - val_Recall: 0.7565 - val_accuracy: 0.7391 - val_loss: 0.5203
# Epoch 59/60
# 92/92 - 7s - 79ms/step - Precision: 0.7344 - Recall: 0.7033 - accuracy: 0.7245 - loss: 0.5400 - val_Precision: 0.7807 - val_Recall: 0.6348 - val_accuracy: 0.7283 - val_loss: 0.5238
# Epoch 60/60
# 92/92 - 7s - 81ms/step - Precision: 0.7282 - Recall: 0.6989 - accuracy: 0.7190 - loss: 0.5326 - val_Precision: 0.8072 - val_Recall: 0.5826 - val_accuracy: 0.7217 - val_loss: 0.5305

# %%
#weights saving
model.save("classifier.keras")

# %% [markdown]
# ## Results

# %% [markdown]
# plotting the history of train and validation loss, accurcy, precision, recall

# %%
import matplotlib.pyplot as plt
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
acc = history.history['Precision']
val_acc = history.history['val_Precision']
loss = history.history['Recall']
val_loss = history.history['val_Recall']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training Precision')
plt.plot(epochs, val_acc, 'b', label='Validation Precision')
plt.title('Training and validation Precision')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Recall')
plt.plot(epochs, val_loss, 'b', label='Validation Recall')
plt.title('Training and validation Recall')
plt.legend()

plt.show()

# %% [markdown]
# Testing

# %%
train_generator.class_indices
# Out:
# {'00-damage': 0, '01-whole': 1}

# %%
validation_generator.class_indices
# Out:
# {'00-damage': 0, '01-whole': 1}

# %%
import cv2
im = cv2.imread("/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a/validation/00-damage/0001.JPEG")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (150, 150))
imS=im.reshape([1,150,150,3])
pred=model.predict(np.array(imS))
if pred[0][0]<0.5:
    print("The car is damaged")
else:
    print("The car is not damaged")
plt.axis("off")
plt.imshow(im)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# The car is damaged

# %%
im = cv2.imread("/root/.cache/kagglehub/datasets/anujms/car-damage-detection/versions/1/data1a/validation/01-whole/0011.jpg")
im = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
im = cv2.resize(im, (150, 150))
imS=im.reshape([1,150,150,3])
pred=model.predict(np.array(imS))
print(pred)
if pred[0][0]<0.5:
    print("The car is damaged")
else:
    print("The car is not damaged")
plt.axis("off")
plt.imshow(im)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [[0.74833214]]
# The car is not damaged

# %% [markdown]
# Conclusion: Successfully build a classifier to classify the images containing into damage and undamage cars.

# %% [markdown]
# # Inference - SURA data

# %%
# Clone the GitHub repo
repo_url = "https://github.com/slunara/car_damage_detector.git"
# !git clone {repo_url}

test_data_dir = "car_damage_detector/test_data"

assert os.path.exists(test_data_dir), "Test data folder not found!"
print("Test data downloaded successfully!")
# Out:
# Cloning into 'car_damage_detector'...
# remote: Enumerating objects: 471, done.
# remote: Counting objects: 100% (212/212), done.
# remote: Compressing objects: 100% (206/206), done.
# remote: Total 471 (delta 59), reused 15 (delta 6), pack-reused 259 (from 3)
# Receiving objects: 100% (471/471), 148.06 MiB | 26.74 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# Updating files: 100% (244/244), done.
# Test data downloaded successfully!

# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# Define image size
IMG_SIZE = (150, 150)

# Define class labels (damage = 0, whole = 1)
class_labels = {"damage": 0, "whole": 1}

# Function to load and preprocess images
def load_and_preprocess_image(image_path):
    img = load_img(image_path, target_size=IMG_SIZE)  # Load and resize
    img_array = img_to_array(img)  # Convert to numpy array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Normalize
    return img_array

# Function to load test images from both classes
def load_test_images(test_data_dir):
    test_images = []
    test_labels = []
    test_filenames = []

    for category in ["damage", "whole"]:  # Iterate over both classes
        folder_path = os.path.join(test_data_dir, category)

        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            img_array = load_and_preprocess_image(img_path)
            test_images.append(img_array)
            test_labels.append(class_labels[category])
            test_filenames.append(img_name)

    return np.vstack(test_images), np.array(test_labels), test_filenames

# Load test images
X_test, y_test, filenames = load_test_images(test_data_dir)

print(f"✅ Loaded {len(X_test)} test images!")
# Out:
# ✅ Loaded 144 test images!

# %%
# Make predictions
y_pred = model.predict(X_test)
y_pred_labels = (y_pred > 0.5).astype(int)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 23s 3s/step

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# Assuming y_test and y_pred_labels are already defined
# y_test: True labels (flattened if needed)
# y_pred_labels: Predicted labels

# ✅ Calculate Accuracy
accuracy = accuracy_score(y_test.flatten(), y_pred_labels)

# ✅ Calculate Precision for Class 0 (Damaged Cars)
precision_damage = precision_score(y_test.flatten(), y_pred_labels, pos_label=0)

# ✅ Calculate Recall for Class 0 (Damaged Cars)
recall_damage = recall_score(y_test.flatten(), y_pred_labels, pos_label=0)

# ✅ Print the results
print(f"Model Performance Metrics:")
print(f"Accuracy: {accuracy* 100:.2f}%")
print(f"Precision for Damaged Cars (Class 0): {precision_damage* 100:.2f}%")
print(f"Recall for Damaged Cars (Class 0): {recall_damage* 100:.2f}%")
# Out:
# Model Performance Metrics:
# Accuracy: 84.03%
# Precision for Damaged Cars (Class 0): 0.00%
# Recall for Damaged Cars (Class 0): 0.00%

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix


y_pred_labels = y_pred_labels.flatten()

cm = confusion_matrix(y_test, y_pred_labels)

# Plot confusion matrix
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Damaged (0)", "Whole (1)"],
            yticklabels=["Damaged (0)", "Whole (1)"])
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.title("Confusion Matrix (Fixed)")
plt.show()

# %%
from sklearn.metrics import roc_curve, auc

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)  # Use probabilities
roc_auc = auc(fpr, tpr)  # Compute AUC

# Plot ROC Curve
plt.figure(figsize=(6, 4))
plt.plot(fpr, tpr, color="blue", lw=2, label=f"AUC = {roc_auc:.2f}")
plt.plot([0, 1], [0, 1], color="gray", linestyle="--")  # Diagonal reference line
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel("False Positive Rate (FPR)")
plt.ylabel("True Positive Rate (TPR)")
plt.title("ROC Curve")
plt.legend(loc="lower right")
plt.show()

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.efficientnet_v2 import preprocess_input

# Define image size
IMG_SIZE = (150, 150)

# Define class labels (damage = 0, whole = 1)
class_labels = {"damage": 0, "whole": 1}

# Function to load and preprocess images
def load_and_preprocess_image(image_path):
    img = load_img(image_path, target_size=IMG_SIZE)  # Load and resize
    img_array = img_to_array(img)  # Convert to numpy array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array = preprocess_input(img_array)  # Normalize
    return img_array

# Function to load test images from both classes
def load_test_images(test_data_dir):
    test_images = []
    test_labels = []
    test_filenames = []
    test_filepaths = []  # Store full paths for loading images later

    for category in ["damage", "whole"]:  # Iterate over both classes
        folder_path = os.path.join(test_data_dir, category)

        for img_name in os.listdir(folder_path):
            img_path = os.path.join(folder_path, img_name)
            img_array = load_and_preprocess_image(img_path)
            test_images.append(img_array)
            test_labels.append(class_labels[category])
            test_filenames.append(img_name)
            test_filepaths.append(img_path)  # Store full path

    return np.vstack(test_images), np.array(test_labels), test_filenames, test_filepaths

# Load test images
X_test, y_test, filenames, filepaths = load_test_images(test_data_dir)

print(f"✅ Loaded {len(X_test)} test images!")
# Out:
# ✅ Loaded 144 test images!

# %%
# 🔍 Filter images where predicted probability is below 0.2
low_confidence_indices = np.where(y_pred < 0.5)[0]  # Get indices of low-confidence predictions
low_confidence_images = [filepaths[i] for i in low_confidence_indices]
low_confidence_actual = [y_test[i] for i in low_confidence_indices]
low_confidence_pred = [y_pred_labels[i] for i in low_confidence_indices]
low_confidence_probs = [y_pred[i] for i in low_confidence_indices]

# ✅ Check if there are any low-confidence images before creating subplots
if len(low_confidence_images) > 0:
    # ✅ Display the images with their actual & corrected predicted confidence
    fig, axes = plt.subplots(nrows=len(low_confidence_images), figsize=(8, len(low_confidence_images) * 3))

    for i, img_path in enumerate(low_confidence_images):
        img = load_img(img_path, target_size=(300, 300))  # Load with larger size
        axes[i].imshow(img)
        axes[i].axis("off")

        # Determine actual and predicted labels
        actual_label = "Damaged" if low_confidence_actual[i] == 0 else "Whole"
        predicted_label = "Damaged" if low_confidence_pred[i] == 0 else "Whole"

        # ✅ Correct confidence calculation
        if low_confidence_pred[i] == 1:  # If predicted "Whole"
            probability = low_confidence_probs[i][0] * 100  # Confidence in class 1 # Extract the value from the array
        else:  # If predicted "Damaged"
            probability = (1 - low_confidence_probs[i][0]) * 100  # Confidence in class 0 # Extract the value from the array

        # ✅ Set title with corrected confidence
        axes[i].set_title(f"Actual: {actual_label} | Predicted: {predicted_label}\nConfidence: {probability:.1f}%")

    plt.tight_layout()
    plt.show()
else:
    print("✅ No low-confidence images found.") # Print a message if no low-confidence images are found.
